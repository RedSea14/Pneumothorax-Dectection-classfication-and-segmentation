# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydicom
# !pip install vit-keras
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.4.1-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.9 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.10.1)
# Collecting validators (from vit-keras)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.22.4)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators->vit-keras) (4.4.2)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=97c8188a797c1fe8f835551023070e1117ed2f85c32072ff423435ed22c3b98c
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
# Successfully built validators
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.20.0 vit-keras-0.1.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.20.0 typeguard-2.13.3

# %%
import pandas as pd
import numpy as np
from glob import glob
import glob2
from tqdm import tqdm
import shutil
import os
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image
import warnings
from joblib import Parallel, delayed
warnings.filterwarnings("ignore")
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import keras
# tf.enable_eager_execution()
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# from hilbert import hilbertCurve
import imgaug.augmenters as iaa
import numpy as np
import random as rn
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau, Callback
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# import tensorflow.keras.applications.efficientnet as efn
from tensorflow.keras import Sequential
from keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications import densenet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, AveragePooling2D

from tensorflow import reduce_sum
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPool2D, Dropout, concatenate, Flatten
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from skimage.transform import resize
import tensorflow as tf
import keras.backend as K
from keras.losses import binary_crossentropy

from tensorflow.keras.utils import load_img
from keras import Model
from keras.callbacks import  ModelCheckpoint
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout,BatchNormalization
from keras.layers import Conv2D, Concatenate, MaxPooling2D
from keras.layers import UpSampling2D, Dropout, BatchNormalization
from tqdm import tqdm_notebook
from keras import initializers
from keras import regularizers
from keras import constraints
from keras.utils import conv_utils
from keras.utils.data_utils import get_file
from keras.utils.layer_utils import get_source_inputs
from keras.layers import InputSpec
from keras import backend as K
from keras.layers import LeakyReLU
from keras.layers import ZeroPadding2D
from keras.losses import binary_crossentropy
import keras.callbacks as callbacks
from keras.callbacks import Callback
from keras.applications.xception import Xception
from keras.layers import multiply


from keras import optimizers
#from keras.legacy import interfaces
from tensorflow.keras.utils import get_custom_objects

from tensorflow.keras.layers import Input
from keras.engine.training import Model
from keras.layers.convolutional import Conv2D, UpSampling2D, Conv2DTranspose
from keras.layers.core import Activation, SpatialDropout2D
from tensorflow.keras.layers import concatenate,add
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
)
from keras.layers.pooling import MaxPooling2D
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add
from keras.regularizers import l2
from keras.layers.core import Dense, Lambda
from keras.layers import GlobalAveragePooling2D, Reshape, Dense, multiply, Permute
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

import glob
import shutil
import os
import random
from PIL import Image
# !pip install pydicom
# !pip install segmentation-models-3D
# !pip install tensorflow_io
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
from tqdm import tqdm_notebook as tqdm
import sys
import glob
import pydicom

# https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
from tensorflow.keras.applications import EfficientNetB4
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import preprocessing
from tensorflow.keras import applications
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.losses import binary_crossentropy
from keras import backend as K


# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle
from tqdm import tqdm_notebook as tqdm
import sys
import glob2
import cv2
from sklearn.model_selection import train_test_split
import random as rn
import shutil
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import os
import pydicom
from keras.preprocessing import image
from matplotlib.pyplot import imread
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, classification_report , accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from scipy.spatial import distance
import segmentation_models_3D as sm

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve,roc_auc_score , auc
from keras.utils.np_utils import to_categorical
import cv2
import gc
from keras.metrics import MeanIoU
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.applications import MobileNetV2 , VGG16 , ResNet50
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from IPython.display import clear_output
from keras.metrics import MeanIoU
from datetime import date
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation-models-3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from segmentation-models-3D) (2.12.0)
# Collecting keras-applications>=1.0.8 (from segmentation-models-3D)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.8 MB/s eta 0:00:00
# Collecting classification-models-3D>=1.0.6 (from segmentation-models-3D)
#   Downloading classification_models_3D-1.0.7-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications>=1.0.8->segmentation-models-3D) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications>=1.0.8->segmentation-models-3D) (3.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.54.2)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.8.0->segmentation-models-3D) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation-models-3D) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.8.0->segmentation-models-3D) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow>=2.8.0->segmentation-models-3D) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.8.0->segmentation-models-3D) (3.2.2)
# Installing collected packages: classification-models-3D, keras-applications, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.7 keras-applications-1.0.8 segmentation-models-3D-1.0.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io) (0.32.0)
# Installing collected packages: tensorflow_io
# Successfully installed tensorflow_io-0.32.0
# Segmentation Models: using `tf.keras` framework.

# %%
cd /content/drive/MyDrive/KhoaLuan/DATASET
# Out:
# /content/drive/MyDrive/KhoaLuan/DATASET

# %%
final_train_df = pd.read_csv('Train Dataset/siim/final_train_data.csv')
final_train_df.head(2)
# Out:
#                                              ImageId  \
# 0  1.2.276.0.7230010.3.1.4.8323329.6904.151787520...
# 1  1.2.276.0.7230010.3.1.4.8323329.13666.15178752...
#
#                                        EncodedPixels  \
# 0                                                 -1
# 1  557374 2 1015 8 1009 14 1002 20 997 26 990 32 ...
#
#                                            ImagePath  \
# 0  Train Dataset/siim/train_dicom_images/1.2.276....
# 1  Train Dataset/siim/train_dicom_images/1.2.276....
#
#                                             MaskPath  \
# 0  Train Dataset/siim/train_mask_png_images/1.2.2...
# 1  Train Dataset/siim/train_mask_png_images/1.2.2...
#
#                                        ImagePath_Png
# 0  Train Dataset/siim/train_png_images/1.2.276.0....
# 1  Train Dataset/siim/train_png_images/1.2.276.0....

# %%
# Creating folders for .png files

train_png_dest = '/content/drive/MyDrive/KhoaLuan/DATASET/Train Dataset/siim/train_png_images'
#test_png_dest = 'Train Dataset/siim/test_png_images'

if not os.path.isdir(train_png_dest):
    os.makedirs(train_png_dest)
'''if not os.path.isdir(test_png_dest):
    os.makedirs(test_png_dest)'''
# Out:
# 'if not os.path.isdir(test_png_dest):\n    os.makedirs(test_png_dest)'

# %%
imagePath = '/content/drive/MyDrive/KhoaLuan/DATASET/Train Dataset/siim/train_png_images/'

# %%
final_train_df['Target'] = final_train_df['EncodedPixels'].apply(lambda x : 0 if x == '-1' else 1)

# %%
final_train_df.head(2)
# Out:
#                                              ImageId  \
# 0  1.2.276.0.7230010.3.1.4.8323329.6904.151787520...
# 1  1.2.276.0.7230010.3.1.4.8323329.13666.15178752...
#
#                                        EncodedPixels  \
# 0                                                 -1
# 1  557374 2 1015 8 1009 14 1002 20 997 26 990 32 ...
#
#                                            ImagePath  \
# 0  Train Dataset/siim/train_dicom_images/1.2.276....
# 1  Train Dataset/siim/train_dicom_images/1.2.276....
#
#                                             MaskPath  \
# 0  Train Dataset/siim/train_mask_png_images/1.2.2...
# 1  Train Dataset/siim/train_mask_png_images/1.2.2...
#
#                                        ImagePath_Png  Target
# 0  Train Dataset/siim/train_png_images/1.2.276.0....       0
# 1  Train Dataset/siim/train_png_images/1.2.276.0....       1

# %%
imagePath = final_train_df['ImagePath_Png']

# %%
imagePath
# Out:
# 0        Train Dataset/siim/train_png_images/1.2.276.0....
# 1        Train Dataset/siim/train_png_images/1.2.276.0....
# 2        Train Dataset/siim/train_png_images/1.2.276.0....
# 3        Train Dataset/siim/train_png_images/1.2.276.0....
# 4        Train Dataset/siim/train_png_images/1.2.276.0....
#                                ...
# 12042    Train Dataset/siim/train_png_images/1.2.276.0....
# 12043    Train Dataset/siim/train_png_images/1.2.276.0....
# 12044    Train Dataset/siim/train_png_images/1.2.276.0....
# 12045    Train Dataset/siim/train_png_images/1.2.276.0....
# 12046    Train Dataset/siim/train_png_images/1.2.276.0....
# Name: ImagePath_Png, Length: 12047, dtype: object

# %%
labels = final_train_df["Target"]

# %%
trainPath, validPath, trainLabels, validLabels = train_test_split(imagePath, labels, test_size = 0.2, random_state = 27, stratify=labels)

# %%
print('Total Train Dataset Size : ', trainPath.shape[0])
print('Total Valid Dataset Size : ', validPath.shape[0])
# Out:
# Total Train Dataset Size :  9637
# Total Valid Dataset Size :  2410

# %%
import random

# %%
def build_decoder(with_labels=True, target_size=(300, 300)):
    def decode(path):
        file_bytes = tf.io.read_file(path)
        img = tf.image.decode_png(file_bytes, channels=3)
        img = tf.cast(img, tf.float32) / 255.0
        img = tf.image.resize(img, target_size)

        return img

    def decode_with_labels(path, label):
        return decode(path), label

    return decode_with_labels if with_labels else decode

def build_augmenter(with_labels=True):
    def augment(img):
        number = random.randint(1,5)
        seed = (1, 5)
        if number == 1:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.stateless_random_contrast(img,0.2, 0.5,seed)
        if number == 2:
            img = tf.image.stateless_random_flip_up_down(img,seed)
            img = tf.image.stateless_random_brightness(img, 0.2,seed)
        if number == 3:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.stateless_random_saturation(img, 0.2, 0.5,seed)
        if number == 4:
            img = tf.image.stateless_random_flip_up_down(img,seed)
            img = tf.image.stateless_random_hue(img, 0.2,seed)
        if number == 5:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.adjust_gamma(img, 0.2)
        return img

    def augment_with_labels(img, label):
        return augment(img), label

    return augment_with_labels if with_labels else augment

def build_dataset(paths, labels=None, bsize=32, cache=True,
                  decode_fn=None, augment_fn=None,
                  augment=True, repeat=True, shuffle=1024,cache_dir=""):
    if cache_dir != "" and cache is True:
        os.makedirs(cache_dir, exist_ok=True)

    if decode_fn is None:
        decode_fn = build_decoder(labels is not None)

    if augment_fn is None:
        augment_fn = build_augmenter(labels is not None)

    AUTO = tf.data.experimental.AUTOTUNE
    slices = paths if labels is None else (paths, labels)

    dset = tf.data.Dataset.from_tensor_slices(slices)
    dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.cache(cache_dir) if cache else dset
    dset = dset.map(augment_fn, num_parallel_calls=AUTO) if augment else dset
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)

    return dset

# %%
#Building the decoder for building the Train and Valid Dataset:

decoder = build_decoder(with_labels=True, target_size=(256, 256))
print(decoder)
# Out:
# <function build_decoder.<locals>.decode_with_labels at 0x7f8f74b24e50>

# %%
#Creating the Augmented Train and Valid Datasets:

dtrain = build_dataset(
    trainPath, trainLabels, bsize=16, decode_fn=decoder,cache_dir='Kaggle5/tf_cache'
)

dvalid = build_dataset(
    validPath, validLabels, bsize=16,
    repeat=False, shuffle=False, augment=False, decode_fn=decoder,cache_dir='Kaggle5/tf_cache'
)

# %%
print('Train Dataset : ',dtrain)
print('Valid Dataset : ',dvalid)
# Out:
# Train Dataset :  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>
# Valid Dataset :  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
class_weight = {0: neg_weights, 1: pos_weights}

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from vit_keras import vit

def build_vit_model(input_shape):
    # Sử dụng thư viện vit_keras để xây dựng mô hình ViT
    backbone_model = vit.vit_b16(
        image_size=input_shape[:2],
        activation='sigmoid',
        pretrained=True,
        include_top=False,
        pretrained_top=False
    )

    # Đặt các lớp đầu ra sau ViT
    flatten_layer = Flatten()(backbone_model.output)
    dense_layer = Dense(1, activation='sigmoid', name='dense')(flatten_layer)

    # Xây dựng mô hình
    model = Model(inputs=backbone_model.input, outputs=dense_layer)

    return model

# Định dạng đầu vào và ra
input_shape = (256, 256, 3)
# Xây dựng mô hình
final_new_model = build_vit_model(input_shape)
final_new_model.summary()
# Out:
# Downloading data from https://github.com/faustomorales/vit-keras/releases/download/dl/ViT-B_16_imagenet21k+imagenet2012.npz
# 347502902/347502902 [==============================] - 6s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  embedding (Conv2D)          (None, 16, 16, 768)       590592
#
#  reshape (Reshape)           (None, 256, 768)          0
#
#  class_token (ClassToken)    (None, 257, 768)          768
#
#  Transformer/posembed_input   (None, 257, 768)         197376
#  (AddPositionEmbs)
#
#  Transformer/encoderblock_0   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_1   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_2   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_3   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_4   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_5   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_6   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_7   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_8   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_9   ((None, 257, 768),       7087872
#  (TransformerBlock)           (None, 12, None, None))
#
#  Transformer/encoderblock_10  ((None, 257, 768),       7087872
#   (TransformerBlock)          (None, 12, None, None))
#
#  Transformer/encoderblock_11  ((None, 257, 768),       7087872
#   (TransformerBlock)          (None, 12, None, None))
#
#  Transformer/encoder_norm (L  (None, 257, 768)         1536
#  ayerNormalization)
#
#  ExtractToken (Lambda)       (None, 768)               0
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 1)                 769
#
# =================================================================
# Total params: 85,845,505
# Trainable params: 85,845,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
final_new_model.inputs, final_new_model.outputs
# Out:
# ([<KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input_1')>],
#  [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense')>])

# %%
BATCH_SIZE = 16
#total number of datapooints that should be passed through the network in individual epochs. This is used when we are generating data through augmentations
weighted_steps_per_epoch = trainPath.shape[0] // BATCH_SIZE

#Callback for saving the weights
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    '/content/drive/MyDrive/KhoaLuan/Phân Loại/save_models/ViT.h5', save_best_only=True, monitor='accuracy', mode='max',restore_best_weights=True)

#Callback for the ReduceLROnPlateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", patience=3, min_lr=1e-4, mode='max')

#Callback to stop training if the metric value doesnt change for 6 epochs
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0.0001, patience=50, mode='max',restore_best_weights=True)

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
]

#Adam optimizer
optim = tf.keras.optimizers.Adam(0.0001)

# %%
final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
history = final_new_model.fit(
    dtrain,
    epochs=150,
    verbose=1,
    callbacks=[checkpoint, lr_reducer],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    class_weight=class_weight)
# Out:
# Epoch 1/150
# 602/602 [==============================] - 953s 1s/step - loss: 0.1948 - accuracy: 0.6893 - precision: 0.3874 - recall: 0.7144 - auc: 0.7770 - val_loss: 0.3937 - val_accuracy: 0.8286 - val_precision: 0.9074 - val_recall: 0.1952 - val_auc: 0.8919 - lr: 1.0000e-04
# Epoch 2/150
# 602/602 [==============================] - 223s 370ms/step - loss: 0.1522 - accuracy: 0.7874 - precision: 0.5129 - recall: 0.8103 - auc: 0.8758 - val_loss: 0.4222 - val_accuracy: 0.8038 - val_precision: 0.5154 - val_recall: 0.9323 - val_auc: 0.9317 - lr: 1.0000e-04
# Epoch 3/150
# 602/602 [==============================] - 196s 325ms/step - loss: 0.1301 - accuracy: 0.8204 - precision: 0.5625 - recall: 0.8607 - auc: 0.9100 - val_loss: 0.2202 - val_accuracy: 0.8994 - val_precision: 0.7616 - val_recall: 0.7510 - val_auc: 0.9545 - lr: 1.0000e-04
# Epoch 4/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.1053 - accuracy: 0.8562 - precision: 0.6235 - recall: 0.8931 - auc: 0.9401 - val_loss: 0.2335 - val_accuracy: 0.8998 - val_precision: 0.6970 - val_recall: 0.9163 - val_auc: 0.9655 - lr: 1.0000e-04
# Epoch 5/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0845 - accuracy: 0.8914 - precision: 0.6917 - recall: 0.9219 - auc: 0.9616 - val_loss: 0.1775 - val_accuracy: 0.9272 - val_precision: 0.7477 - val_recall: 0.9801 - val_auc: 0.9870 - lr: 1.0000e-04
# Epoch 6/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0738 - accuracy: 0.9041 - precision: 0.7156 - recall: 0.9363 - auc: 0.9701 - val_loss: 0.2110 - val_accuracy: 0.9201 - val_precision: 0.7249 - val_recall: 0.9920 - val_auc: 0.9893 - lr: 1.0000e-04
# Epoch 7/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0540 - accuracy: 0.9350 - precision: 0.7946 - recall: 0.9548 - auc: 0.9834 - val_loss: 0.1204 - val_accuracy: 0.9553 - val_precision: 0.8328 - val_recall: 0.9821 - val_auc: 0.9922 - lr: 1.0000e-04
# Epoch 8/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0518 - accuracy: 0.9343 - precision: 0.7955 - recall: 0.9487 - auc: 0.9850 - val_loss: 0.0673 - val_accuracy: 0.9805 - val_precision: 0.9268 - val_recall: 0.9841 - val_auc: 0.9970 - lr: 1.0000e-04
# Epoch 9/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0389 - accuracy: 0.9570 - precision: 0.8568 - recall: 0.9655 - auc: 0.9913 - val_loss: 0.0410 - val_accuracy: 0.9847 - val_precision: 0.9735 - val_recall: 0.9522 - val_auc: 0.9979 - lr: 1.0000e-04
# Epoch 10/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0349 - accuracy: 0.9604 - precision: 0.8687 - recall: 0.9682 - auc: 0.9930 - val_loss: 0.0935 - val_accuracy: 0.9690 - val_precision: 0.8779 - val_recall: 0.9880 - val_auc: 0.9968 - lr: 1.0000e-04
# Epoch 11/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0295 - accuracy: 0.9658 - precision: 0.8832 - recall: 0.9736 - auc: 0.9947 - val_loss: 0.0339 - val_accuracy: 0.9876 - val_precision: 0.9556 - val_recall: 0.9861 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 12/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0291 - accuracy: 0.9653 - precision: 0.8868 - recall: 0.9684 - auc: 0.9951 - val_loss: 0.1568 - val_accuracy: 0.9313 - val_precision: 0.7617 - val_recall: 0.9741 - val_auc: 0.9912 - lr: 1.0000e-04
# Epoch 13/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0298 - accuracy: 0.9663 - precision: 0.8887 - recall: 0.9679 - auc: 0.9950 - val_loss: 0.0745 - val_accuracy: 0.9656 - val_precision: 0.8606 - val_recall: 0.9960 - val_auc: 0.9991 - lr: 1.0000e-04
# Epoch 14/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0245 - accuracy: 0.9746 - precision: 0.9147 - recall: 0.9766 - auc: 0.9959 - val_loss: 0.0345 - val_accuracy: 0.9880 - val_precision: 0.9610 - val_recall: 0.9821 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 15/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0260 - accuracy: 0.9707 - precision: 0.8988 - recall: 0.9780 - auc: 0.9958 - val_loss: 0.0303 - val_accuracy: 0.9888 - val_precision: 0.9490 - val_recall: 1.0000 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 16/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0150 - accuracy: 0.9821 - precision: 0.9387 - recall: 0.9842 - auc: 0.9982 - val_loss: 0.0065 - val_accuracy: 0.9979 - val_precision: 0.9960 - val_recall: 0.9940 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 17/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0221 - accuracy: 0.9756 - precision: 0.9195 - recall: 0.9763 - auc: 0.9972 - val_loss: 0.0150 - val_accuracy: 0.9950 - val_precision: 0.9920 - val_recall: 0.9841 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 18/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0202 - accuracy: 0.9757 - precision: 0.9142 - recall: 0.9805 - auc: 0.9973 - val_loss: 0.0447 - val_accuracy: 0.9834 - val_precision: 0.9278 - val_recall: 0.9980 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 19/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0175 - accuracy: 0.9802 - precision: 0.9303 - recall: 0.9846 - auc: 0.9979 - val_loss: 0.0108 - val_accuracy: 0.9950 - val_precision: 0.9900 - val_recall: 0.9861 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 20/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0183 - accuracy: 0.9819 - precision: 0.9398 - recall: 0.9818 - auc: 0.9973 - val_loss: 0.0085 - val_accuracy: 0.9979 - val_precision: 1.0000 - val_recall: 0.9900 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 21/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0157 - accuracy: 0.9830 - precision: 0.9414 - recall: 0.9840 - auc: 0.9981 - val_loss: 0.0161 - val_accuracy: 0.9942 - val_precision: 0.9880 - val_recall: 0.9841 - val_auc: 0.9998 - lr: 1.0000e-04
# Epoch 22/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0159 - accuracy: 0.9838 - precision: 0.9449 - recall: 0.9840 - auc: 0.9980 - val_loss: 0.0136 - val_accuracy: 0.9950 - val_precision: 0.9823 - val_recall: 0.9940 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 23/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0168 - accuracy: 0.9821 - precision: 0.9392 - recall: 0.9837 - auc: 0.9982 - val_loss: 0.0123 - val_accuracy: 0.9967 - val_precision: 0.9940 - val_recall: 0.9900 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 24/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0206 - accuracy: 0.9770 - precision: 0.9235 - recall: 0.9771 - auc: 0.9976 - val_loss: 0.0126 - val_accuracy: 0.9950 - val_precision: 1.0000 - val_recall: 0.9761 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 25/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0114 - accuracy: 0.9891 - precision: 0.9632 - recall: 0.9882 - auc: 0.9989 - val_loss: 0.0062 - val_accuracy: 0.9983 - val_precision: 0.9940 - val_recall: 0.9980 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 26/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0136 - accuracy: 0.9867 - precision: 0.9528 - recall: 0.9893 - auc: 0.9985 - val_loss: 0.0137 - val_accuracy: 0.9950 - val_precision: 0.9960 - val_recall: 0.9801 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 27/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0159 - accuracy: 0.9828 - precision: 0.9410 - recall: 0.9841 - auc: 0.9983 - val_loss: 0.0164 - val_accuracy: 0.9950 - val_precision: 0.9960 - val_recall: 0.9801 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 28/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0164 - accuracy: 0.9825 - precision: 0.9388 - recall: 0.9844 - auc: 0.9980 - val_loss: 0.0038 - val_accuracy: 0.9992 - val_precision: 1.0000 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 29/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0127 - accuracy: 0.9881 - precision: 0.9613 - recall: 0.9860 - auc: 0.9989 - val_loss: 0.0294 - val_accuracy: 0.9888 - val_precision: 0.9490 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 30/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0144 - accuracy: 0.9838 - precision: 0.9446 - recall: 0.9851 - auc: 0.9984 - val_loss: 0.0692 - val_accuracy: 0.9752 - val_precision: 0.8932 - val_recall: 1.0000 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 31/150
# 602/602 [==============================] - 198s 329ms/step - loss: 0.0155 - accuracy: 0.9838 - precision: 0.9413 - recall: 0.9877 - auc: 0.9982 - val_loss: 0.0142 - val_accuracy: 0.9942 - val_precision: 0.9747 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 32/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0132 - accuracy: 0.9859 - precision: 0.9509 - recall: 0.9874 - auc: 0.9984 - val_loss: 0.0897 - val_accuracy: 0.9665 - val_precision: 0.8623 - val_recall: 0.9980 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 33/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0117 - accuracy: 0.9868 - precision: 0.9537 - recall: 0.9882 - auc: 0.9989 - val_loss: 0.0065 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 34/150
# 602/602 [==============================] - 195s 325ms/step - loss: 0.0124 - accuracy: 0.9876 - precision: 0.9571 - recall: 0.9888 - auc: 0.9988 - val_loss: 0.0098 - val_accuracy: 0.9963 - val_precision: 0.9960 - val_recall: 0.9861 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 35/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0110 - accuracy: 0.9884 - precision: 0.9599 - recall: 0.9887 - auc: 0.9990 - val_loss: 0.0031 - val_accuracy: 0.9988 - val_precision: 0.9960 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 36/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0115 - accuracy: 0.9871 - precision: 0.9548 - recall: 0.9888 - auc: 0.9985 - val_loss: 0.0227 - val_accuracy: 0.9934 - val_precision: 0.9709 - val_recall: 0.9980 - val_auc: 0.9996 - lr: 1.0000e-04
# Epoch 37/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0126 - accuracy: 0.9880 - precision: 0.9555 - recall: 0.9915 - auc: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9946 - val_precision: 0.9785 - val_recall: 0.9960 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 38/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0110 - accuracy: 0.9889 - precision: 0.9622 - recall: 0.9888 - auc: 0.9990 - val_loss: 0.0134 - val_accuracy: 0.9959 - val_precision: 0.9980 - val_recall: 0.9821 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 39/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0156 - accuracy: 0.9818 - precision: 0.9373 - recall: 0.9841 - auc: 0.9981 - val_loss: 0.0045 - val_accuracy: 0.9983 - val_precision: 0.9940 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 40/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0123 - accuracy: 0.9866 - precision: 0.9518 - recall: 0.9897 - auc: 0.9988 - val_loss: 0.0097 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 41/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0087 - accuracy: 0.9911 - precision: 0.9684 - recall: 0.9920 - auc: 0.9994 - val_loss: 0.0077 - val_accuracy: 0.9967 - val_precision: 0.9843 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 42/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0131 - accuracy: 0.9876 - precision: 0.9581 - recall: 0.9873 - auc: 0.9984 - val_loss: 0.0082 - val_accuracy: 0.9971 - val_precision: 0.9882 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 43/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0077 - accuracy: 0.9940 - precision: 0.9787 - recall: 0.9944 - auc: 0.9991 - val_loss: 0.0153 - val_accuracy: 0.9963 - val_precision: 0.9843 - val_recall: 0.9980 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 44/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0988 - accuracy: 0.8627 - precision: 0.6478 - recall: 0.8421 - auc: 0.9460 - val_loss: 0.0220 - val_accuracy: 0.9930 - val_precision: 0.9919 - val_recall: 0.9741 - val_auc: 0.9996 - lr: 1.0000e-04
# Epoch 45/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0165 - accuracy: 0.9836 - precision: 0.9457 - recall: 0.9815 - auc: 0.9983 - val_loss: 0.0156 - val_accuracy: 0.9934 - val_precision: 0.9728 - val_recall: 0.9960 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 46/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0133 - accuracy: 0.9882 - precision: 0.9607 - recall: 0.9875 - auc: 0.9985 - val_loss: 0.0127 - val_accuracy: 0.9946 - val_precision: 0.9980 - val_recall: 0.9761 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 47/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0056 - accuracy: 0.9943 - precision: 0.9793 - recall: 0.9953 - auc: 0.9997 - val_loss: 0.0022 - val_accuracy: 0.9992 - val_precision: 0.9980 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 48/150
# 602/602 [==============================] - 198s 329ms/step - loss: 0.0135 - accuracy: 0.9832 - precision: 0.9414 - recall: 0.9849 - auc: 0.9985 - val_loss: 0.0143 - val_accuracy: 0.9938 - val_precision: 0.9803 - val_recall: 0.9900 - val_auc: 0.9998 - lr: 1.0000e-04
# Epoch 49/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0251 - accuracy: 0.9719 - precision: 0.9066 - recall: 0.9744 - auc: 0.9963 - val_loss: 0.0055 - val_accuracy: 0.9983 - val_precision: 0.9940 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 50/150
# 602/602 [==============================] - 195s 324ms/step - loss: 0.0087 - accuracy: 0.9910 - precision: 0.9672 - recall: 0.9930 - auc: 0.9993 - val_loss: 0.0049 - val_accuracy: 0.9988 - val_precision: 0.9980 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 51/150
# 602/602 [==============================] - 195s 324ms/step - loss: 0.0079 - accuracy: 0.9914 - precision: 0.9689 - recall: 0.9930 - auc: 0.9994 - val_loss: 6.9111e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 52/150
# 602/602 [==============================] - 195s 324ms/step - loss: 0.0101 - accuracy: 0.9892 - precision: 0.9632 - recall: 0.9887 - auc: 0.9989 - val_loss: 0.0898 - val_accuracy: 0.9648 - val_precision: 0.8576 - val_recall: 0.9960 - val_auc: 0.9981 - lr: 1.0000e-04
# Epoch 53/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0143 - accuracy: 0.9850 - precision: 0.9478 - recall: 0.9869 - auc: 0.9987 - val_loss: 0.0113 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 54/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0104 - accuracy: 0.9881 - precision: 0.9564 - recall: 0.9911 - auc: 0.9989 - val_loss: 0.2395 - val_accuracy: 0.9412 - val_precision: 0.9813 - val_recall: 0.7311 - val_auc: 0.9570 - lr: 1.0000e-04
# Epoch 55/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0376 - accuracy: 0.9556 - precision: 0.8599 - recall: 0.9544 - auc: 0.9922 - val_loss: 0.0088 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 56/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0073 - accuracy: 0.9918 - precision: 0.9729 - recall: 0.9906 - auc: 0.9997 - val_loss: 0.0010 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 57/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0080 - accuracy: 0.9927 - precision: 0.9771 - recall: 0.9907 - auc: 0.9994 - val_loss: 0.0070 - val_accuracy: 0.9979 - val_precision: 0.9901 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 58/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0062 - accuracy: 0.9935 - precision: 0.9772 - recall: 0.9934 - auc: 0.9996 - val_loss: 0.0025 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 59/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0276 - accuracy: 0.9669 - precision: 0.8928 - recall: 0.9668 - auc: 0.9960 - val_loss: 0.0292 - val_accuracy: 0.9901 - val_precision: 0.9878 - val_recall: 0.9641 - val_auc: 0.9992 - lr: 1.0000e-04
# Epoch 60/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0146 - accuracy: 0.9847 - precision: 0.9485 - recall: 0.9851 - auc: 0.9985 - val_loss: 0.0073 - val_accuracy: 0.9959 - val_precision: 0.9843 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 61/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0058 - accuracy: 0.9933 - precision: 0.9769 - recall: 0.9929 - auc: 0.9996 - val_loss: 0.0034 - val_accuracy: 0.9988 - val_precision: 0.9941 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 62/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0124 - accuracy: 0.9870 - precision: 0.9536 - recall: 0.9892 - auc: 0.9986 - val_loss: 0.0038 - val_accuracy: 0.9992 - val_precision: 0.9980 - val_recall: 0.9980 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 63/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0036 - accuracy: 0.9965 - precision: 0.9871 - recall: 0.9972 - auc: 0.9997 - val_loss: 3.6508e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 64/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0060 - accuracy: 0.9949 - precision: 0.9811 - recall: 0.9963 - auc: 0.9992 - val_loss: 0.0089 - val_accuracy: 0.9967 - val_precision: 0.9980 - val_recall: 0.9861 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 65/150
# 602/602 [==============================] - 194s 322ms/step - loss: 0.0072 - accuracy: 0.9922 - precision: 0.9712 - recall: 0.9944 - auc: 0.9994 - val_loss: 0.0083 - val_accuracy: 0.9971 - val_precision: 0.9901 - val_recall: 0.9960 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 66/150
# 602/602 [==============================] - 194s 322ms/step - loss: 0.0109 - accuracy: 0.9885 - precision: 0.9591 - recall: 0.9901 - auc: 0.9989 - val_loss: 0.0013 - val_accuracy: 0.9992 - val_precision: 0.9980 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 67/150
# 602/602 [==============================] - 194s 322ms/step - loss: 0.0054 - accuracy: 0.9945 - precision: 0.9813 - recall: 0.9939 - auc: 0.9995 - val_loss: 0.0147 - val_accuracy: 0.9938 - val_precision: 0.9880 - val_recall: 0.9821 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 68/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0096 - accuracy: 0.9906 - precision: 0.9694 - recall: 0.9888 - auc: 0.9990 - val_loss: 0.0176 - val_accuracy: 0.9946 - val_precision: 0.9920 - val_recall: 0.9821 - val_auc: 0.9998 - lr: 1.0000e-04
# Epoch 69/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0083 - accuracy: 0.9925 - precision: 0.9735 - recall: 0.9935 - auc: 0.9991 - val_loss: 0.0045 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 70/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0128 - accuracy: 0.9861 - precision: 0.9499 - recall: 0.9892 - auc: 0.9985 - val_loss: 0.0030 - val_accuracy: 0.9988 - val_precision: 0.9941 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 71/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0050 - accuracy: 0.9952 - precision: 0.9824 - recall: 0.9962 - auc: 0.9996 - val_loss: 0.0055 - val_accuracy: 0.9979 - val_precision: 0.9960 - val_recall: 0.9940 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 72/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0112 - accuracy: 0.9884 - precision: 0.9577 - recall: 0.9911 - auc: 0.9989 - val_loss: 0.0041 - val_accuracy: 0.9988 - val_precision: 0.9980 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 73/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0064 - accuracy: 0.9931 - precision: 0.9756 - recall: 0.9945 - auc: 0.9997 - val_loss: 0.0107 - val_accuracy: 0.9959 - val_precision: 0.9824 - val_recall: 0.9980 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 74/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0311 - accuracy: 0.9635 - precision: 0.8766 - recall: 0.9708 - auc: 0.9942 - val_loss: 0.0096 - val_accuracy: 0.9971 - val_precision: 0.9920 - val_recall: 0.9940 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 75/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0169 - accuracy: 0.9828 - precision: 0.9412 - recall: 0.9830 - auc: 0.9980 - val_loss: 0.0139 - val_accuracy: 0.9967 - val_precision: 0.9920 - val_recall: 0.9920 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 76/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0186 - accuracy: 0.9797 - precision: 0.9265 - recall: 0.9870 - auc: 0.9974 - val_loss: 0.0089 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 77/150
# 602/602 [==============================] - 194s 322ms/step - loss: 0.0254 - accuracy: 0.9710 - precision: 0.9014 - recall: 0.9761 - auc: 0.9962 - val_loss: 0.0100 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 78/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0065 - accuracy: 0.9940 - precision: 0.9784 - recall: 0.9948 - auc: 0.9994 - val_loss: 0.0297 - val_accuracy: 0.9917 - val_precision: 0.9617 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 79/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0019 - accuracy: 0.9984 - precision: 0.9930 - recall: 1.0000 - auc: 0.9999 - val_loss: 0.0086 - val_accuracy: 0.9983 - val_precision: 0.9921 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 80/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0086 - accuracy: 0.9913 - precision: 0.9681 - recall: 0.9935 - auc: 0.9991 - val_loss: 0.0675 - val_accuracy: 0.9793 - val_precision: 0.9094 - val_recall: 1.0000 - val_auc: 0.9977 - lr: 1.0000e-04
# Epoch 81/150
# 602/602 [==============================] - 196s 325ms/step - loss: 0.0081 - accuracy: 0.9910 - precision: 0.9679 - recall: 0.9920 - auc: 0.9996 - val_loss: 0.0060 - val_accuracy: 0.9988 - val_precision: 0.9980 - val_recall: 0.9960 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 82/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0076 - accuracy: 0.9913 - precision: 0.9691 - recall: 0.9925 - auc: 0.9995 - val_loss: 0.0135 - val_accuracy: 0.9963 - val_precision: 0.9824 - val_recall: 1.0000 - val_auc: 0.9995 - lr: 1.0000e-04
# Epoch 83/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0081 - accuracy: 0.9921 - precision: 0.9723 - recall: 0.9925 - auc: 0.9992 - val_loss: 0.0295 - val_accuracy: 0.9905 - val_precision: 0.9579 - val_recall: 0.9980 - val_auc: 0.9994 - lr: 1.0000e-04
# Epoch 84/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0069 - accuracy: 0.9940 - precision: 0.9802 - recall: 0.9930 - auc: 0.9996 - val_loss: 0.0332 - val_accuracy: 0.9868 - val_precision: 0.9401 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 85/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0127 - accuracy: 0.9852 - precision: 0.9478 - recall: 0.9868 - auc: 0.9988 - val_loss: 0.0053 - val_accuracy: 0.9988 - val_precision: 0.9980 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 86/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0047 - accuracy: 0.9950 - precision: 0.9821 - recall: 0.9958 - auc: 0.9997 - val_loss: 0.0119 - val_accuracy: 0.9963 - val_precision: 0.9862 - val_recall: 0.9960 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 87/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0075 - accuracy: 0.9914 - precision: 0.9687 - recall: 0.9929 - auc: 0.9996 - val_loss: 0.0035 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 88/150
# 602/602 [==============================] - 194s 322ms/step - loss: 0.0055 - accuracy: 0.9936 - precision: 0.9762 - recall: 0.9953 - auc: 0.9996 - val_loss: 0.0126 - val_accuracy: 0.9971 - val_precision: 0.9960 - val_recall: 0.9900 - val_auc: 0.9989 - lr: 1.0000e-04
# Epoch 89/150
# 602/602 [==============================] - 194s 322ms/step - loss: 0.0102 - accuracy: 0.9898 - precision: 0.9653 - recall: 0.9897 - auc: 0.9989 - val_loss: 0.0055 - val_accuracy: 0.9975 - val_precision: 1.0000 - val_recall: 0.9880 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 90/150
# 602/602 [==============================] - 209s 348ms/step - loss: 0.0116 - accuracy: 0.9881 - precision: 0.9561 - recall: 0.9915 - auc: 0.9985 - val_loss: 0.4798 - val_accuracy: 0.9081 - val_precision: 0.9348 - val_recall: 0.5996 - val_auc: 0.8699 - lr: 1.0000e-04
# Epoch 91/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.1630 - accuracy: 0.7285 - precision: 0.4353 - recall: 0.7582 - auc: 0.8399 - val_loss: 0.4108 - val_accuracy: 0.8179 - val_precision: 0.5459 - val_recall: 0.7351 - val_auc: 0.8739 - lr: 1.0000e-04
# Epoch 92/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.1035 - accuracy: 0.8681 - precision: 0.6532 - recall: 0.8590 - auc: 0.9441 - val_loss: 0.0833 - val_accuracy: 0.9706 - val_precision: 0.8925 - val_recall: 0.9761 - val_auc: 0.9964 - lr: 1.0000e-04
# Epoch 93/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0219 - accuracy: 0.9757 - precision: 0.9175 - recall: 0.9785 - auc: 0.9974 - val_loss: 0.0095 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 94/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0064 - accuracy: 0.9941 - precision: 0.9798 - recall: 0.9939 - auc: 0.9993 - val_loss: 0.0020 - val_accuracy: 0.9992 - val_precision: 0.9980 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 95/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0069 - accuracy: 0.9934 - precision: 0.9759 - recall: 0.9943 - auc: 0.9996 - val_loss: 0.0050 - val_accuracy: 0.9988 - val_precision: 0.9941 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 96/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0044 - accuracy: 0.9954 - precision: 0.9842 - recall: 0.9953 - auc: 0.9996 - val_loss: 0.0032 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 97/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0043 - accuracy: 0.9960 - precision: 0.9865 - recall: 0.9953 - auc: 0.9996 - val_loss: 0.0129 - val_accuracy: 0.9946 - val_precision: 0.9748 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 98/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0114 - accuracy: 0.9870 - precision: 0.9536 - recall: 0.9897 - auc: 0.9990 - val_loss: 0.0121 - val_accuracy: 0.9954 - val_precision: 0.9823 - val_recall: 0.9960 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 99/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0108 - accuracy: 0.9891 - precision: 0.9625 - recall: 0.9892 - auc: 0.9989 - val_loss: 0.0039 - val_accuracy: 0.9992 - val_precision: 1.0000 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 100/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0052 - accuracy: 0.9945 - precision: 0.9814 - recall: 0.9939 - auc: 0.9995 - val_loss: 0.0022 - val_accuracy: 0.9988 - val_precision: 1.0000 - val_recall: 0.9940 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 101/150
# 602/602 [==============================] - 198s 329ms/step - loss: 0.0110 - accuracy: 0.9892 - precision: 0.9631 - recall: 0.9892 - auc: 0.9989 - val_loss: 0.0389 - val_accuracy: 0.9880 - val_precision: 0.9454 - val_recall: 1.0000 - val_auc: 0.9996 - lr: 1.0000e-04
# Epoch 102/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0064 - accuracy: 0.9939 - precision: 0.9781 - recall: 0.9949 - auc: 0.9994 - val_loss: 0.0017 - val_accuracy: 0.9996 - val_precision: 1.0000 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 103/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0117 - accuracy: 0.9899 - precision: 0.9657 - recall: 0.9891 - auc: 0.9985 - val_loss: 0.0141 - val_accuracy: 0.9959 - val_precision: 0.9805 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 104/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0107 - accuracy: 0.9890 - precision: 0.9620 - recall: 0.9898 - auc: 0.9987 - val_loss: 0.0093 - val_accuracy: 0.9971 - val_precision: 0.9901 - val_recall: 0.9960 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 105/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0033 - accuracy: 0.9971 - precision: 0.9897 - recall: 0.9972 - auc: 0.9997 - val_loss: 0.0049 - val_accuracy: 0.9983 - val_precision: 0.9960 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 106/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0052 - accuracy: 0.9951 - precision: 0.9820 - recall: 0.9962 - auc: 0.9993 - val_loss: 0.0168 - val_accuracy: 0.9930 - val_precision: 0.9672 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 107/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0081 - accuracy: 0.9900 - precision: 0.9655 - recall: 0.9907 - auc: 0.9994 - val_loss: 0.0020 - val_accuracy: 0.9996 - val_precision: 1.0000 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 108/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0052 - accuracy: 0.9952 - precision: 0.9833 - recall: 0.9953 - auc: 0.9996 - val_loss: 0.0031 - val_accuracy: 0.9992 - val_precision: 0.9980 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 109/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0086 - accuracy: 0.9916 - precision: 0.9686 - recall: 0.9938 - auc: 0.9990 - val_loss: 0.0123 - val_accuracy: 0.9959 - val_precision: 0.9881 - val_recall: 0.9920 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 110/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0098 - accuracy: 0.9893 - precision: 0.9608 - recall: 0.9926 - auc: 0.9992 - val_loss: 0.0109 - val_accuracy: 0.9959 - val_precision: 0.9843 - val_recall: 0.9960 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 111/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0065 - accuracy: 0.9931 - precision: 0.9747 - recall: 0.9948 - auc: 0.9994 - val_loss: 3.9503e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 112/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0075 - accuracy: 0.9925 - precision: 0.9725 - recall: 0.9944 - auc: 0.9994 - val_loss: 0.0033 - val_accuracy: 0.9988 - val_precision: 0.9941 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 113/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0075 - accuracy: 0.9912 - precision: 0.9684 - recall: 0.9925 - auc: 0.9994 - val_loss: 0.0093 - val_accuracy: 0.9954 - val_precision: 0.9786 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 114/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0042 - accuracy: 0.9965 - precision: 0.9874 - recall: 0.9967 - auc: 0.9996 - val_loss: 0.0056 - val_accuracy: 0.9988 - val_precision: 1.0000 - val_recall: 0.9940 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 115/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0120 - accuracy: 0.9860 - precision: 0.9489 - recall: 0.9902 - auc: 0.9987 - val_loss: 0.0108 - val_accuracy: 0.9950 - val_precision: 0.9767 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 116/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0098 - accuracy: 0.9885 - precision: 0.9584 - recall: 0.9911 - auc: 0.9994 - val_loss: 0.0020 - val_accuracy: 0.9996 - val_precision: 1.0000 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 117/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0049 - accuracy: 0.9948 - precision: 0.9819 - recall: 0.9948 - auc: 0.9997 - val_loss: 0.0036 - val_accuracy: 0.9996 - val_precision: 1.0000 - val_recall: 0.9980 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 118/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0042 - accuracy: 0.9969 - precision: 0.9894 - recall: 0.9967 - auc: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9983 - val_precision: 0.9921 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 119/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0028 - accuracy: 0.9972 - precision: 0.9888 - recall: 0.9986 - auc: 0.9999 - val_loss: 0.0036 - val_accuracy: 0.9983 - val_precision: 0.9921 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 120/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0078 - accuracy: 0.9915 - precision: 0.9702 - recall: 0.9920 - auc: 0.9992 - val_loss: 0.0296 - val_accuracy: 0.9892 - val_precision: 0.9508 - val_recall: 1.0000 - val_auc: 0.9994 - lr: 1.0000e-04
# Epoch 121/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0091 - accuracy: 0.9911 - precision: 0.9679 - recall: 0.9925 - auc: 0.9992 - val_loss: 0.0073 - val_accuracy: 0.9979 - val_precision: 0.9980 - val_recall: 0.9920 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 122/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0070 - accuracy: 0.9917 - precision: 0.9712 - recall: 0.9921 - auc: 0.9997 - val_loss: 4.6804e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 123/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0053 - accuracy: 0.9940 - precision: 0.9801 - recall: 0.9930 - auc: 0.9996 - val_loss: 0.0098 - val_accuracy: 0.9983 - val_precision: 0.9921 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 124/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0035 - accuracy: 0.9966 - precision: 0.9874 - recall: 0.9972 - auc: 0.9998 - val_loss: 0.0047 - val_accuracy: 0.9983 - val_precision: 0.9940 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 125/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0061 - accuracy: 0.9945 - precision: 0.9793 - recall: 0.9963 - auc: 0.9988 - val_loss: 0.0070 - val_accuracy: 0.9975 - val_precision: 0.9960 - val_recall: 0.9920 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 126/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0076 - accuracy: 0.9940 - precision: 0.9820 - recall: 0.9911 - auc: 0.9994 - val_loss: 0.0470 - val_accuracy: 0.9843 - val_precision: 0.9296 - val_recall: 1.0000 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 127/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0083 - accuracy: 0.9922 - precision: 0.9710 - recall: 0.9944 - auc: 0.9994 - val_loss: 0.0072 - val_accuracy: 0.9971 - val_precision: 0.9940 - val_recall: 0.9920 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 128/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0045 - accuracy: 0.9955 - precision: 0.9832 - recall: 0.9967 - auc: 0.9997 - val_loss: 0.0010 - val_accuracy: 0.9996 - val_precision: 0.9980 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 129/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0053 - accuracy: 0.9948 - precision: 0.9812 - recall: 0.9958 - auc: 0.9997 - val_loss: 0.0051 - val_accuracy: 0.9983 - val_precision: 0.9921 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 130/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0076 - accuracy: 0.9914 - precision: 0.9689 - recall: 0.9930 - auc: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9996 - val_precision: 0.9980 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 131/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0085 - accuracy: 0.9911 - precision: 0.9679 - recall: 0.9925 - auc: 0.9993 - val_loss: 0.0030 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 132/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0044 - accuracy: 0.9952 - precision: 0.9843 - recall: 0.9944 - auc: 0.9998 - val_loss: 0.0038 - val_accuracy: 0.9988 - val_precision: 0.9980 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 133/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0059 - accuracy: 0.9944 - precision: 0.9812 - recall: 0.9939 - auc: 0.9993 - val_loss: 0.0033 - val_accuracy: 0.9983 - val_precision: 0.9940 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 134/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0042 - accuracy: 0.9955 - precision: 0.9841 - recall: 0.9957 - auc: 0.9998 - val_loss: 0.0017 - val_accuracy: 0.9996 - val_precision: 0.9980 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 135/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0054 - accuracy: 0.9951 - precision: 0.9838 - recall: 0.9944 - auc: 0.9997 - val_loss: 0.0029 - val_accuracy: 0.9988 - val_precision: 0.9960 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 136/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0023 - accuracy: 0.9971 - precision: 0.9894 - recall: 0.9977 - auc: 0.9999 - val_loss: 0.0057 - val_accuracy: 0.9988 - val_precision: 1.0000 - val_recall: 0.9940 - val_auc: 0.9990 - lr: 1.0000e-04
# Epoch 137/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0072 - accuracy: 0.9931 - precision: 0.9748 - recall: 0.9948 - auc: 0.9991 - val_loss: 0.0256 - val_accuracy: 0.9892 - val_precision: 0.9525 - val_recall: 0.9980 - val_auc: 0.9997 - lr: 1.0000e-04
# Epoch 138/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0067 - accuracy: 0.9917 - precision: 0.9708 - recall: 0.9920 - auc: 0.9996 - val_loss: 0.0021 - val_accuracy: 0.9992 - val_precision: 0.9960 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 139/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0050 - accuracy: 0.9953 - precision: 0.9834 - recall: 0.9958 - auc: 0.9995 - val_loss: 9.6135e-04 - val_accuracy: 0.9996 - val_precision: 0.9980 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 140/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0062 - accuracy: 0.9934 - precision: 0.9775 - recall: 0.9930 - auc: 0.9997 - val_loss: 0.0071 - val_accuracy: 0.9975 - val_precision: 0.9882 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 141/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0060 - accuracy: 0.9936 - precision: 0.9773 - recall: 0.9939 - auc: 0.9995 - val_loss: 0.0199 - val_accuracy: 0.9921 - val_precision: 0.9671 - val_recall: 0.9960 - val_auc: 0.9999 - lr: 1.0000e-04
# Epoch 142/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0060 - accuracy: 0.9945 - precision: 0.9798 - recall: 0.9958 - auc: 0.9994 - val_loss: 0.0125 - val_accuracy: 0.9959 - val_precision: 0.9805 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 143/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0038 - accuracy: 0.9963 - precision: 0.9861 - recall: 0.9972 - auc: 0.9999 - val_loss: 6.3653e-04 - val_accuracy: 0.9996 - val_precision: 0.9980 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 144/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0081 - accuracy: 0.9914 - precision: 0.9699 - recall: 0.9921 - auc: 0.9991 - val_loss: 0.0540 - val_accuracy: 0.9834 - val_precision: 0.9262 - val_recall: 1.0000 - val_auc: 0.9986 - lr: 1.0000e-04
# Epoch 145/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0046 - accuracy: 0.9948 - precision: 0.9806 - recall: 0.9963 - auc: 0.9997 - val_loss: 0.0031 - val_accuracy: 0.9988 - val_precision: 0.9980 - val_recall: 0.9960 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 146/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0074 - accuracy: 0.9910 - precision: 0.9667 - recall: 0.9934 - auc: 0.9996 - val_loss: 3.5484e-04 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 147/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0060 - accuracy: 0.9948 - precision: 0.9815 - recall: 0.9953 - auc: 0.9994 - val_loss: 0.0030 - val_accuracy: 0.9988 - val_precision: 0.9960 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 148/150
# 602/602 [==============================] - 195s 323ms/step - loss: 0.0053 - accuracy: 0.9941 - precision: 0.9783 - recall: 0.9953 - auc: 0.9994 - val_loss: 0.0068 - val_accuracy: 0.9983 - val_precision: 0.9940 - val_recall: 0.9980 - val_auc: 1.0000 - lr: 1.0000e-04
# Epoch 149/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0027 - accuracy: 0.9968 - precision: 0.9879 - recall: 0.9976 - auc: 0.9998 - val_loss: 0.0252 - val_accuracy: 0.9909 - val_precision: 0.9598 - val_recall: 0.9980 - val_auc: 0.9998 - lr: 1.0000e-04
# Epoch 150/150
# 602/602 [==============================] - 194s 323ms/step - loss: 0.0072 - accuracy: 0.9922 - precision: 0.9738 - recall: 0.9916 - auc: 0.9993 - val_loss: 0.0330 - val_accuracy: 0.9863 - val_precision: 0.9383 - val_recall: 1.0000 - val_auc: 1.0000 - lr: 1.0000e-04

# %%
acc = history.history['accuracy']
loss = history.history['loss']
auc = history.history['auc']
precision = history.history['precision']
recall = history.history['recall']

val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
val_auc = history.history['val_auc']
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']

# %%
import sklearn
from sklearn import metrics
from sklearn.metrics import confusion_matrix,precision_recall_curve,average_precision_score,accuracy_score

# %%
#Plotting the metrics:

plt.figure(figsize=(15, 15))

#Plotting the Accuracy:
plt.subplot(3, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.xlabel('Epoch')
plt.title('Training and Validation Accuracy')

#Plotting the Loss:
plt.subplot(3, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')

#Plotting the AUC:
plt.subplot(3, 2, 3)
plt.plot(auc, label='Training AUC')
plt.plot(val_auc, label='Validation AUC')
plt.legend(loc='lower right')
plt.ylabel('AUC')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation AUC')
plt.xlabel('Epoch')

#Plotting the Precision:
plt.subplot(3, 2, 4)
plt.plot(precision, label='Training Precision')
plt.plot(val_precision, label='Validation Precision')
plt.legend(loc='upper right')
plt.ylabel('Precision')
plt.ylim([0,1.0])
plt.title('Training and Validation Precision')
plt.xlabel('Epoch')

#Plotting the Recall:
plt.subplot(3, 2, 5)
plt.plot(recall, label='Training Recall')
plt.plot(val_recall, label='Validation Recall')
plt.legend(loc='lower right')
plt.ylabel('Recall')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Recall')
plt.xlabel('Epoch')

#Showing all the graphs:
plt.show()

# %%
test_decoder = build_decoder(with_labels=False, target_size=(256, 256))

train_features = build_dataset(
    trainPath, bsize=BATCH_SIZE, repeat=False,
    shuffle=False, augment=False, cache=False,
    decode_fn=test_decoder
)

valid_features = build_dataset(
    validPath, bsize=BATCH_SIZE, repeat=False,
    shuffle=False, augment=False, cache=False,
    decode_fn=test_decoder
)

# %%
valid_predictions_baseline = final_new_model.predict(valid_features, batch_size=16)
valid_baseline_results = final_new_model.evaluate(dvalid,batch_size=16, verbose=0)
# Out:
# 151/151 [==============================] - 212s 1s/step

# %%
val_precision = round((valid_baseline_results[2]),5)
val_recall = round((valid_baseline_results[3]),5)
val_loss = round((valid_baseline_results[0]),5)
val_accuracy=round((valid_baseline_results[1]),5)
val_auc = round((valid_baseline_results[4]),5)
print('METRIC VALUES FOR VALID DATASET : \n')
print('PRECISION : ', val_precision)
print('RECALL : ', val_recall)
print('ACCURACY : ', val_accuracy)
print('LOSS : ', val_loss)
print('AUC : ', val_auc)
# Out:
# METRIC VALUES FOR VALID DATASET :
#
# PRECISION :  0.93832
# RECALL :  1.0
# ACCURACY :  0.98634
# LOSS :  0.03301
# AUC :  0.99999

# %%
def plot_roc(name, labels, predictions):
  fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)
  auc = round(metrics.auc(fp, tp),3)

  plt.figure(figsize=(8, 8))
  plt.plot(100*fp, 100*tp, label=name+" = " +str(auc), linewidth=2)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.grid(True)
  plt.title("ROC Curve")
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
#Plotting the ROC Curve on CV Dataset:
plot_roc("CV Baseline", validLabels, valid_predictions_baseline)
plt.legend(loc='lower right')

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  tn = cm[0][0]
  fn = cm[1][0]
  fp = cm[0][1]
  tp = cm[1][1]

  sensitivity = round((tp/(tp+fn)),3)
  specificity = round((tn/(tn+fp)),3)
  accuracy = round(((tp + tn)/(tp+tn+fp+fn)),3)
  PPV = round((tp/(tp + fp)),3)
  NPV = round((tn/(tn + fn)),3)
  print('Total Records Detected : ', labels.shape[0])
  print('Total Pneumothorax Cases : ', np.sum(cm[1]))
  print("=====================================")
  print('True Negatives : ', tn)
  print('False Positives : ', fp)
  print('False Negatives : ', fn)
  print('True Positives : ', tp)
  print("=====================================")
  print('Accuracy : ', accuracy)
  print('PPV : ', PPV)
  print('NPV : ', NPV)
  print('Sensitivity : ', sensitivity)
  print('Specificity : ', specificity)
  print("=====================================")

  return tn,fn,fp,tp,sensitivity,specificity,accuracy,PPV,NPV

# %%
tn,fn,fp,tp,sensitivity,specificity,accuracy,PPV,NPV = plot_cm(validLabels, valid_predictions_baseline)
# Out:
# Total Records Detected :  2410
# Total Pneumothorax Cases :  534
# =====================================
# True Negatives :  1587
# False Positives :  289
# False Negatives :  178
# True Positives :  356
# =====================================
# Accuracy :  0.806
# PPV :  0.552
# NPV :  0.899
# Sensitivity :  0.667
# Specificity :  0.846
# =====================================

# %%
final_new_model.load_weights("/content/drive/MyDrive/KhoaLuan/Phân Loại/save_models/ViT.h5")

# %%
valid_predictions_baseline = final_new_model.predict(valid_features, batch_size=16)
valid_baseline_results = final_new_model.evaluate(dvalid,batch_size=16, verbose=0)
# Out:
# 151/151 [==============================] - 17s 111ms/step

# %%
def read_image(path):

    x = tf.io.read_file(path)
    x = tf.image.decode_png(x, channels=3)
    x = tf.image.convert_image_dtype(x, tf.float32)

    return x

def classify_decode(path):
    file_bytes = tf.io.read_file(path)
    img = tf.image.decode_png(file_bytes, channels=3)
    img = tf.cast(img, tf.float32) / 255.0

    return img

# %%
def Predict(final_classify_model, image_path):
    """
    This function predicts the classfication output and if it is greater than 0.5 it passes the image to the segmentation model.
    ------------------------------------------------------------------
    final_classify_model      : saved classification model instance
    final_segment_model       : saved segmentation model instance
    image_path                : image path
    ------------------------------------------------------------------
    """

     # read the original image
    image_orig = classify_decode(image_path)

    #get the classification output
    classify_output = final_classify_model.predict(tf.expand_dims(image_orig, axis=0))
    confidence = classify_output

    # checking the threshold:
    if confidence > 0.5:
        print('Pneumothorax Found..!!')
        print('Classifier Prediction Confidence : {}%'.format(classify_output*100))
    else:
        print('No Pneumothorax Detection...!')
        no_confidence = 1 - classify_output
        print('Classifier Prediction Confidence : {}%'.format(no_confidence*100))

# %%
test=final_train_df['ImagePath_Png'].head(11)

# %%
test
# Out:
# 0     Train Dataset/siim/train_png_images/1.2.276.0....
# 1     Train Dataset/siim/train_png_images/1.2.276.0....
# 2     Train Dataset/siim/train_png_images/1.2.276.0....
# 3     Train Dataset/siim/train_png_images/1.2.276.0....
# 4     Train Dataset/siim/train_png_images/1.2.276.0....
# 5     Train Dataset/siim/train_png_images/1.2.276.0....
# 6     Train Dataset/siim/train_png_images/1.2.276.0....
# 7     Train Dataset/siim/train_png_images/1.2.276.0....
# 8     Train Dataset/siim/train_png_images/1.2.276.0....
# 9     Train Dataset/siim/train_png_images/1.2.276.0....
# 10    Train Dataset/siim/train_png_images/1.2.276.0....
# Name: ImagePath_Png, dtype: object

# %%
for image_path in test:
    print(image_path)
    Predict(final_new_model, image_path)
# Out:
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6904.1517875201.850819.png
# 1/1 [==============================] - 0s 48ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.9597]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13666.1517875247.117800.png
# 1/1 [==============================] - 0s 44ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.973335]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11028.1517875229.983789.png
# 1/1 [==============================] - 0s 46ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.925804]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10366.1517875223.393986.png
# 1/1 [==============================] - 0s 45ms/step
# Pneumothorax Found..!!
# Classifier Prediction Confidence : [[96.61873]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10016.1517875220.992175.png
# 1/1 [==============================] - 0s 45ms/step
# Pneumothorax Found..!!
# Classifier Prediction Confidence : [[77.82141]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11444.1517875232.977506.png
# 1/1 [==============================] - 0s 44ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.98709]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32219.1517875159.70802.png
# 1/1 [==============================] - 0s 45ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.98271]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32395.1517875160.396775.png
# 1/1 [==============================] - 0s 45ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.98101]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10623.1517875224.585561.png
# 1/1 [==============================] - 0s 48ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.90549]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12095.1517875237.355858.png
# 1/1 [==============================] - 0s 44ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.86215]]%
# Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3514.1517875178.176496.png
# 1/1 [==============================] - 0s 50ms/step
# No Pneumothorax Detection...!
# Classifier Prediction Confidence : [[99.81947]]%
